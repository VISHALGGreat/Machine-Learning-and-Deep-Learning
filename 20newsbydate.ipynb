# %%
import pandas as pd

# %%
import numpy as np

# %%
import pickle

# %%
from keras.preprocessing.text import Tokenizer
# Out:
# F:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras.models import Sequential

# %%
from keras.layers import Activation, Dense, Dropout

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
import sklearn.datasets as skds

# %%
from pathlib import Path

# %%
np.random.seed(1237)

# %%
path_train = "C:\\Users\\Vishal\\Desktop\\DEEPLearning\\new_data\\20news-bydate\\20news-bydate-train"

# %%
files_train = skds.load_files(path_train,load_content=False)

# %%
label_index = files_train.target

# %%
label_names = files_train.target_names

# %%
labelled_files = files_train.filenames

# %%
data_tags = ["filename","category","news"]

# %%
data_list = []

# %%
i=0
for f in labelled_files:
    data_list.append((f,label_names[label_index[i]],Path(f).read_text()))
    i += 1

# %%
data = pd.DataFrame.from_records(data_list, columns=data_tags)

# %%
data
# Out:
#                                                 filename  \
# 0      C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 1      C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 2      C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 3      C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 4      C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 5      C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 6      C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 7      C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 8      C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 9      C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 10     C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 11     C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 12     C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 13     C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# 14     C:\Users\Vishal\Desktop\DEEPLearning\new_data\...
# ...

# %%
train_size = int(len(data) * .8)
train_posts = data['news'][:train_size]
train_tags = data['category'][:train_size]
train_files_names = data['filename'][:train_size]
 
test_posts = data['news'][train_size:]
test_tags = data['category'][train_size:]
test_files_names = data['filename'][train_size:]

# %%
train_posts
# Out:
# 0       From: cubbie@garnet.berkeley.edu (            ...
# 1       From: gnelson@pion.rutgers.edu (Gregory Nelson...
# 2       From: crypt-comments@math.ncsu.edu\nSubject: C...
# 3       From:  ()\nSubject: Re: Quadra SCSI Problems??...
# 4       From: keith@cco.caltech.edu (Keith Allan Schne...
# 5       From: taihou@chromium.iss.nus.sg (Tng Tai Hou)...
# 6       From: huub@cwi.nl (Huub Bakker)\nSubject: wait...
# 7       From: lanzo@tekelec.com (Mark Lanzo)\nSubject:...
# 8       Subject: Why isolate it?\nFrom: chinsz@eis.cal...
# 9       From: seema@madvlsi.columbia.edu (Seema Varma)...
# 10      From: maler@vercors.imag.fr (Oded Maler)\nSubj...
# 11      From: george@minster.york.ac.uk\nSubject: Non-...
# 12      From: williac@govonca.gov.on.ca (Chris William...
# 13      From: tpremo@mentor.cc.purdue.edu (Cinnamon Be...
# 14      From: toml@boulder.parcplace.com (Tom LaStrang...
# 15      From: ayari@judikael.loria.fr (Ayari Iskander)...
# ...

# %%
train_tags
# Out:
# 0             rec.sport.baseball
# 1          comp.sys.mac.hardware
# 2                      sci.crypt
# 3          comp.sys.mac.hardware
# 4                    alt.atheism
# 5          comp.sys.mac.hardware
# 6                 comp.windows.x
# 7                 comp.windows.x
# 8                        sci.med
# 9                sci.electronics
# 10         talk.politics.mideast
# 11                     sci.crypt
# 12              rec.sport.hockey
# 13                  misc.forsale
# 14                comp.windows.x
# 15              rec.sport.hockey
# 16                     rec.autos
# 17       comp.os.ms-windows.misc
# 18                     sci.crypt
# 19               rec.motorcycles
# 20       comp.os.ms-windows.misc
# 21            rec.sport.baseball
# 22                     rec.autos
# 23                     sci.crypt
# 24                  misc.forsale
# 25                       sci.med
# 26                     sci.space
# 27                     rec.autos
# ...

# %%
# 20 news groups
num_labels = 20
vocab_size = 15000
batch_size = 100

# %%
# define Tokenizer with Vocab Size
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(train_posts)

# %%
x_train = tokenizer.texts_to_matrix(train_posts, mode='tfidf')
x_test = tokenizer.texts_to_matrix(test_posts, mode='tfidf')

# %%
encoder = LabelBinarizer()
encoder.fit(train_tags)
y_train = encoder.transform(train_tags)
y_test = encoder.transform(test_tags)

# %%
encoder = LabelBinarizer()
encoder.fit(train_tags)
y_train = encoder.transform(train_tags)
y_test = encoder.transform(test_tags)

# %%
model = Sequential()
model.add(Dense(512, input_shape=(vocab_size,)))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(num_labels))
model.add(Activation('softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 512)               7680512
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_2 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 20)                10260
# ...

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Train on 8145 samples, validate on 906 samples
# Epoch 1/30
# 8145/8145 [==============================] - 34s 4ms/step - loss: 1.1725 - acc: 0.6939 - val_loss: 0.3978 - val_acc: 0.8896
# Epoch 2/30
# 8145/8145 [==============================] - 29s 4ms/step - loss: 0.1312 - acc: 0.9729 - val_loss: 0.3801 - val_acc: 0.9018
# Epoch 3/30
# 8145/8145 [==============================] - 26s 3ms/step - loss: 0.0673 - acc: 0.9902 - val_loss: 0.5023 - val_acc: 0.8896
# Epoch 4/30
# 8145/8145 [==============================] - 26s 3ms/step - loss: 0.0535 - acc: 0.9919 - val_loss: 0.4777 - val_acc: 0.8896
# Epoch 5/30
# 8145/8145 [==============================] - 26s 3ms/step - loss: 0.0331 - acc: 0.9963 - val_loss: 0.4490 - val_acc: 0.9029
# Epoch 6/30
# 8145/8145 [==============================] - 26s 3ms/step - loss: 0.0316 - acc: 0.9964 - val_loss: 0.4456 - val_acc: 0.9040
# Epoch 7/30
# ...

# %%
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=30,
                    verbose=1,
                    validation_split=0.1)
# Out:
# Train on 8145 samples, validate on 906 samples
# Epoch 1/30
# 8145/8145 [==============================] - 27s 3ms/step - loss: 0.0381 - acc: 0.9964 - val_loss: 0.8625 - val_acc: 0.8808
# Epoch 2/30
# 8145/8145 [==============================] - 25s 3ms/step - loss: 0.0391 - acc: 0.9961 - val_loss: 0.8831 - val_acc: 0.8786
# Epoch 3/30
# 8145/8145 [==============================] - 25s 3ms/step - loss: 0.0345 - acc: 0.9963 - val_loss: 0.8322 - val_acc: 0.8786
# Epoch 4/30
# 8145/8145 [==============================] - 26s 3ms/step - loss: 0.0277 - acc: 0.9974 - val_loss: 0.7928 - val_acc: 0.8929
# Epoch 5/30
# 8145/8145 [==============================] - 27s 3ms/step - loss: 0.0289 - acc: 0.9974 - val_loss: 0.8900 - val_acc: 0.8852
# Epoch 6/30
# 8145/8145 [==============================] - 26s 3ms/step - loss: 0.0307 - acc: 0.9974 - val_loss: 0.8817 - val_acc: 0.8797
# Epoch 7/30
# ...

# %%
score = model.evaluate(x_test, y_test,batch_size=batch_size, verbose=1)
# Out:
# 2263/2263 [==============================] - 17s 8ms/step

# %%
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.8784798960531911

# %%
text_labels = encoder.classes_
 
for i in range(10):
    prediction = model.predict(np.array([x_test[i]]))
    predicted_label = text_labels[np.argmax(prediction[0])]
    print(test_files_names.iloc[i])
    print('Actual label:' + test_tags.iloc[i])
    print("Predicted label: " + predicted_label)
# Out:
# C:\Users\Vishal\Desktop\DEEPLearning\new_data\20news-bydate\20news-bydate-train\alt.atheism\53114
# Actual label:alt.atheism
# Predicted label: alt.atheism
# C:\Users\Vishal\Desktop\DEEPLearning\new_data\20news-bydate\20news-bydate-train\comp.graphics\38666
# Actual label:comp.graphics
# Predicted label: comp.graphics
# C:\Users\Vishal\Desktop\DEEPLearning\new_data\20news-bydate\20news-bydate-train\sci.med\58932
# Actual label:sci.med
# Predicted label: sci.med
# C:\Users\Vishal\Desktop\DEEPLearning\new_data\20news-bydate\20news-bydate-train\sci.crypt\15212
# Actual label:sci.crypt
# Predicted label: sci.crypt
# C:\Users\Vishal\Desktop\DEEPLearning\new_data\20news-bydate\20news-bydate-train\comp.os.ms-windows.misc\9695
# Actual label:comp.os.ms-windows.misc
# Predicted label: comp.sys.ibm.pc.hardware
# C:\Users\Vishal\Desktop\DEEPLearning\new_data\20news-bydate\20news-bydate-train\rec.sport.baseball\104482
# Actual label:rec.sport.baseball
# Predicted label: rec.sport.baseball
# ...

# %%
# creates a HDF5 file 'my_model.h5'
model.model.save('my_model.h5')
 
# Save Tokenizer i.e. Vocabulary
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# F:\Anaconda\lib\site-packages\keras\engine\sequential.py:110: UserWarning: `Sequential.model` is deprecated. `Sequential` is a subclass of `Model`, you can just use your `Sequential` instance directly.
#   warnings.warn('`Sequential.model` is deprecated. '

# %%
from keras.models import load_model
# load our saved model
model = load_model('my_model.h5')
 
# load tokenizer
tokenizer = Tokenizer()
with open('tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
encoder.classes_ #LabelBinarizer
# Out:
# array(['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc',
#        'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware',
#        'comp.windows.x', 'misc.forsale', 'rec.autos', 'rec.motorcycles',
#        'rec.sport.baseball', 'rec.sport.hockey', 'sci.crypt',
#        'sci.electronics', 'sci.med', 'sci.space',
#        'soc.religion.christian', 'talk.politics.guns',
#        'talk.politics.mideast', 'talk.politics.misc',
#        'talk.religion.misc'], dtype='<U24')

# %%
# These are the labels we stored from our training
# The order is very important here.
 
labels = np.array(['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc',
 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware', 'comp.windows.x',
 'misc.forsale', 'rec.autos', 'rec.motorcycles', 'rec.sport.baseball',
 'rec.sport.hockey', 'sci.crypt', 'sci.electronics', 'sci.med', 'sci.space',
 'soc.religion.christian', 'talk.politics.guns', 'talk.politics.mideast',
 'talk.politics.misc', 'talk.religion.misc'])
 
test_files = ["C:\\Users\\Vishal\\Desktop\\DEEPLearning\\new_data\\20news-bydate\\20news-bydate-test\\comp.graphics\\38758",
              "C:\\Users\\Vishal\\Desktop\\DEEPLearning\\new_data\\20news-bydate\\20news-bydate-test\\misc.forsale\\76115",
              "C:\\Users\\Vishal\\Desktop\\DEEPLearning\\new_data\\20news-bydate\\20news-bydate-test\\soc.religion.christian\\21329"
              ]
x_data = []
for t_f in test_files:
    t_f_data = Path(t_f).read_text()
    x_data.append(t_f_data)
 
x_data_series = pd.Series(x_data)
x_tokenized = tokenizer.texts_to_matrix(x_data_series, mode='tfidf')
 
i=0
for x_t in x_tokenized:
    prediction = model.predict(np.array([x_t]))
    predicted_label = labels[np.argmax(prediction[0])]
    print("File ->", test_files[i], "Predicted label: " + predicted_label)
    i += 1
# Out:
# File -> C:\Users\Vishal\Desktop\DEEPLearning\new_data\20news-bydate\20news-bydate-test\comp.graphics\38758 Predicted label: comp.graphics
# File -> C:\Users\Vishal\Desktop\DEEPLearning\new_data\20news-bydate\20news-bydate-test\misc.forsale\76115 Predicted label: comp.sys.ibm.pc.hardware
# File -> C:\Users\Vishal\Desktop\DEEPLearning\new_data\20news-bydate\20news-bydate-test\soc.religion.christian\21329 Predicted label: soc.religion.christian
